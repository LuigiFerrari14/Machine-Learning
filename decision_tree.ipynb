# %% [markdown]
# # 1 Imports

# %%
from sklearn import datasets as dt
from sklearn import tree as tr
from matplotlib import pyplot as plt

# %% [markdown]
# # 2 Load dataset

# %%
iris = dt.load_iris()

X = iris.data[:, 2:]
y = iris.target

# %% [markdown]
# # 3 Model Training

# %%
#define
model_tree = tr.DecisionTreeClassifier()
#model_tree = tr.DecisionTreeClassifier(max_depth=3) -> Controle do tamanho maximo de quebras da arvore. O tamanho maximo de crescimento da arvore ou a quantidade de recortes do espaço.
#min_samples_leaf = o numero minimo de amostras que a folha seguinte deve ter após a divisao
#min_samples_split = o numero minimo de amostras que a folha deve ter para gerar um novo split
#max_features = o numero maximo de atributos avaliados para a divisao


#training
model_tree.fit(X, y)

#predict
# Out:
# DecisionTreeClassifier()

# %%
#view
tr.export_graphviz(
    model_tree,
    out_file='tree.dot',
    feature_names=iris.feature_names[2:],
    class_names=iris.target_names,
    rounded=True,
    filled=True
)

# %% [markdown]
# ![image.png](attachment:image.png)
